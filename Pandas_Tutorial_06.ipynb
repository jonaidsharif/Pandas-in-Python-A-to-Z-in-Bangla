# %% [markdown]
# <a href="https://colab.research.google.com/github/jonaidsharif/Pandas-in-Python-A-to-Z-in-Bangla/blob/main/Pandas_Tutorial_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # import library pandas, name direction pd
import numpy as np

# %%
# Python Dictionary

people_dict = {
    "first_name": "Jonaid Bin",
    "last_name": "Sharif",
    "email": "jonaidsharif@gmail.com",
    "company": "icu ac bd"
}

# %%
# Python Dictionary

more_people = {
    "matrix id": ["C201111", "C201129", "C201342", "C234214", "C123334", "C447233"],
    "first_name": ["Abdullah", "Mubian", "Ayub", "Tashfeen", "Huraain", "Jibon"],
    "last_name": ["Kareem", "Khannan", "Bodda", "Ahmeed", "Kalina", "Moron"],
    "email": ["abullah@gmail.com", "mubian@gmail.com", "ayubxtb@gmail.com", "Tashfeeeene@gmail.com", "Huraaineeei@gmail.com", "Jiboneimoren@gmail.com"],
    "company": ["ecologox", "brain station 23", "lead bd", "appcode", "sumsung r & d", "googleeiie"]
}

# %%
df = pd.DataFrame(more_people)

df
# Out:
#   matrix id first_name last_name                   email           company
# 0   C201111   Abdullah    Kareem       abullah@gmail.com          ecologox
# 1   C201129     Mubian   Khannan        mubian@gmail.com  brain station 23
# 2   C201342       Ayub     Bodda       ayubxtb@gmail.com           lead bd
# 3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com           appcode
# 4   C123334    Huraain    Kalina   Huraaineeei@gmail.com     sumsung r & d
# 5   C447233      Jibon     Moron  Jiboneimoren@gmail.com        googleeiie

# %%
# Apply Function - Series & Data Frame

df['first_name'].apply(len) #word length count
# Out:
# 0    8
# 1    6
# 2    4
# 3    8
# 4    7
# 5    5
# Name: first_name, dtype: int64

# %%
def custom_func(x):
  return x.upper()

# %%
df['first_name'].apply(custom_func)
# Out:
# 0    ABDULLAH
# 1      MUBIAN
# 2        AYUB
# 3    TASHFEEN
# 4     HURAAIN
# 5       JIBON
# Name: first_name, dtype: object

# %%
df
# Out:
#   matrix id first_name last_name                   email           company
# 0   C201111   Abdullah    Kareem       abullah@gmail.com          ecologox
# 1   C201129     Mubian   Khannan        mubian@gmail.com  brain station 23
# 2   C201342       Ayub     Bodda       ayubxtb@gmail.com           lead bd
# 3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com           appcode
# 4   C123334    Huraain    Kalina   Huraaineeei@gmail.com     sumsung r & d
# 5   C447233      Jibon     Moron  Jiboneimoren@gmail.com        googleeiie

# %%
df.apply(len)  # Column name word count!!!
# Out:
# matrix id     6
# first_name    6
# last_name     6
# email         6
# company       6
# dtype: int64

# %%
len(df['matrix id'])
# Out:
# 6

# %%
df.applymap(len) # Every Column individual series word count!!!
# Out:
#    matrix id  first_name  last_name  email  company
# 0          7           8          6     17        8
# 1          7           6          7     16       16
# 2          7           4          5     17        7
# 3          7           8          6     21        7
# 4          7           7          6     21       13
# 5          7           5          5     22       10

# %%
df.apply(len, axis=1)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# dtype: int64

# %%
df
# Out:
#   matrix id first_name last_name                   email           company
# 0   C201111   Abdullah    Kareem       abullah@gmail.com          ecologox
# 1   C201129     Mubian   Khannan        mubian@gmail.com  brain station 23
# 2   C201342       Ayub     Bodda       ayubxtb@gmail.com           lead bd
# 3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com           appcode
# 4   C123334    Huraain    Kalina   Huraaineeei@gmail.com     sumsung r & d
# 5   C447233      Jibon     Moron  Jiboneimoren@gmail.com        googleeiie

# %%
df['first_name'].replace({'Abdullah': 'Alamin', 'Ayub': 'Ayubieee'}) # Replace mention which name this name changed
#another to the name same showing to the result
# Out:
# 0      Alamin
# 1      Mubian
# 2    Ayubieee
# 3    Tashfeen
# 4     Huraain
# 5       Jibon
# Name: first_name, dtype: object

# %%
df['first_name'].map({'Abdullah': 'Alamin', 'Ayub': 'Ayubieee'}) # Replace mention which name this name changed
#another to the name same showing to the result - NaN
# Out:
# 0      Alamin
# 1         NaN
# 2    Ayubieee
# 3         NaN
# 4         NaN
# 5         NaN
# Name: first_name, dtype: object
