# %% [markdown]
# <a href="https://colab.research.google.com/github/jonaidsharif/Pandas-in-Python-A-to-Z-in-Bangla/blob/main/Pandas_Tutorial_03_05_with_loc_and_iloc_07_with_fltr_09_with_setIndex%2C_resetIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas # already install at colab
import pandas as pd # import library pandas, name direction pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Machine Learning/heart_disease_uci.csv")

# %%
df #All Information Describe
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.columns # All columns name showing simply
# Out:
# Index(['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs',
#        'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
df.loc[915] # indexing 916 about all information showing
# Out:
# id                       916
# age                       54
# sex                   Female
# dataset        VA Long Beach
# cp              asymptomatic
# trestbps               127.0
# chol                   333.0
# fbs                     True
# restecg     st-t abnormality
# thalch                 154.0
# exang                  False
# oldpeak                  0.0
# slope                    NaN
# ca                       NaN
# thal                     NaN
# num                        1
# Name: 915, dtype: object

# %%
df.loc[500] # indexing 501 about all information showing
# Out:
# id                   501
# age                   40
# sex                 Male
# dataset          Hungary
# cp          asymptomatic
# trestbps           120.0
# chol               466.0
# fbs                  NaN
# restecg           normal
# thalch             152.0
# exang               True
# oldpeak              1.0
# slope               flat
# ca                   NaN
# thal        fixed defect
# num                    1
# Name: 500, dtype: object

# %%
df.set_index('id') # unique id showing, but not showing index and its not permanetly, thats temporary
# Out:
#      age     sex        dataset               cp  trestbps   chol    fbs  \
# id
# 1     63    Male      Cleveland   typical angina     145.0  233.0   True
# 2     67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 3     67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 4     37    Male      Cleveland      non-anginal     130.0  250.0  False
# 5     41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...     ...            ...              ...       ...    ...    ...
# 916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# id
# ...

# %%
df # updating about dataset
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.set_index('id', inplace = True) # unique id showing, but not showing index and its permanently

# %%
df #Updating about the dataset
# Out:
#      age     sex        dataset               cp  trestbps   chol    fbs  \
# id
# 1     63    Male      Cleveland   typical angina     145.0  233.0   True
# 2     67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 3     67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 4     37    Male      Cleveland      non-anginal     130.0  250.0  False
# 5     41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...     ...            ...              ...       ...    ...    ...
# 916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# id
# ...

# %%
df.reset_index(inplace = True) # reset indexing is the permanently working

# %%
df # Updating about dataset
# Out:
#      age     sex        dataset               cp  trestbps   chol    fbs  \
# id
# 1     63    Male      Cleveland   typical angina     145.0  233.0   True
# 2     67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 3     67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 4     37    Male      Cleveland      non-anginal     130.0  250.0  False
# 5     41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...     ...            ...              ...       ...    ...    ...
# 916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# id
# ...

# %%
df_cleveland = df.loc[fltr] # variable name by declared

# %%
df_cleveland.shape #  row, column
# Out:
# (304, 16)

# %%
fltr = (df['dataset'] == 'Cleveland') | (df['dataset'] == 'Hungary') # variable name decleared of the fltr

# %%
df.loc[fltr] # fltr variable VA Long Beach, Switzerland not showing data and , other data showing
# Out:
#       id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...        ...              ...       ...    ...    ...
# 592  593   52    Male    Hungary     asymptomatic     160.0  331.0  False
# 593  594   54  Female    Hungary      non-anginal     130.0  294.0  False
# 594  595   56    Male    Hungary     asymptomatic     155.0  342.0   True
# 595  596   58  Female    Hungary  atypical angina     180.0  393.0  False
# 596  597   65    Male    Hungary     asymptomatic     130.0  275.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# ...

# %%
df.loc[-fltr] # fltr variable VA Long Beach, Switzerland showing data, other not showing
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 597  598   32    Male    Switzerland   typical angina      95.0    0.0    NaN
# 598  599   34    Male    Switzerland     asymptomatic     115.0    0.0    NaN
# 599  600   35    Male    Switzerland     asymptomatic       NaN    0.0    NaN
# 600  601   36    Male    Switzerland     asymptomatic     110.0    0.0    NaN
# 601  602   38  Female    Switzerland     asymptomatic     105.0    0.0    NaN
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
fltr = (df['dataset'] == 'Cleveland') | (df['dataset'] == 'Hungary') & (df['sex'] == 'Male')

# variable name and cleveland, hungary here which gender is male thats showing to the data decleared of the fltr

# %%
df.loc[fltr] # fltr variable name
# Out:
#       id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...        ...              ...       ...    ...    ...
# 590  591   50    Male    Hungary     asymptomatic     140.0  341.0  False
# 591  592   52    Male    Hungary     asymptomatic     140.0  266.0  False
# 592  593   52    Male    Hungary     asymptomatic     160.0  331.0  False
# 594  595   56    Male    Hungary     asymptomatic     155.0  342.0   True
# 596  597   65    Male    Hungary     asymptomatic     130.0  275.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# ...

# %%
fltrd_df = df.loc[fltr]

# %%
fltrd_df['sex'].value_counts() # checking out sex value how much??!!!
# Out:
# sex
# Male      419
# Female     97
# Name: count, dtype: int64

# %%
fltr_1 = df['age'] >= 40  # age = 40 equal or + this data showing

# %%
df.loc[fltr_1]
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# 5      6   56    Male      Cleveland  atypical angina     120.0  236.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df['age'] #showing about age column data
# Out:
# 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 915    54
# 916    62
# 917    55
# 918    58
# 919    62
# Name: age, Length: 920, dtype: int64

# %%
df.loc[:500, "age":"slope"] # loc with slicing first indexing 500 values showing in the age, slpe
# Out:
#      age     sex    dataset               cp  trestbps   chol    fbs  \
# 0     63    Male  Cleveland   typical angina     145.0  233.0   True
# 1     67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2     67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3     37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4     41  Female  Cleveland  atypical angina     130.0  204.0  False
# ..   ...     ...        ...              ...       ...    ...    ...
# 496   37    Male    Hungary     asymptomatic     140.0  207.0  False
# 497   38    Male    Hungary     asymptomatic     110.0  196.0  False
# 498   38    Male    Hungary     asymptomatic     120.0  282.0  False
# 499   38    Male    Hungary     asymptomatic      92.0  117.0  False
# 500   40    Male    Hungary     asymptomatic     120.0  466.0    NaN
#
#             restecg  thalch  exang  oldpeak        slope
# 0    lv hypertrophy   150.0  False      2.3  downsloping
# ...

# %%
short_df = df.loc[:500, "age":"slope"] # loc with slicing first indexing 500 values showing in the age, slope

# %%
short_df # previous already mentioned the short_df name
# Out:
#      age     sex    dataset               cp  trestbps   chol    fbs  \
# 0     63    Male  Cleveland   typical angina     145.0  233.0   True
# 1     67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2     67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3     37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4     41  Female  Cleveland  atypical angina     130.0  204.0  False
# ..   ...     ...        ...              ...       ...    ...    ...
# 496   37    Male    Hungary     asymptomatic     140.0  207.0  False
# 497   38    Male    Hungary     asymptomatic     110.0  196.0  False
# 498   38    Male    Hungary     asymptomatic     120.0  282.0  False
# 499   38    Male    Hungary     asymptomatic      92.0  117.0  False
# 500   40    Male    Hungary     asymptomatic     120.0  466.0    NaN
#
#             restecg  thalch  exang  oldpeak        slope
# 0    lv hypertrophy   150.0  False      2.3  downsloping
# ...

# %%
df.loc[20:50, "age":"dataset"] # loc with slicing first indexing 20 to 49 values showing in the age started using index 1, dataset ended using index 3
# Out:
#     age     sex    dataset
# 20   64    Male  Cleveland
# 21   58  Female  Cleveland
# 22   58    Male  Cleveland
# 23   58    Male  Cleveland
# 24   60    Male  Cleveland
# 25   50  Female  Cleveland
# 26   58  Female  Cleveland
# 27   66  Female  Cleveland
# 28   43    Male  Cleveland
# 29   40    Male  Cleveland
# 30   69  Female  Cleveland
# 31   60    Male  Cleveland
# 32   64    Male  Cleveland
# 33   59    Male  Cleveland
# 34   44    Male  Cleveland
# 35   42    Male  Cleveland
# 36   43    Male  Cleveland
# 37   57    Male  Cleveland
# 38   55    Male  Cleveland
# 39   61    Male  Cleveland
# 40   65  Female  Cleveland
# 41   40    Male  Cleveland
# 42   71  Female  Cleveland
# 43   59    Male  Cleveland
# 44   61  Female  Cleveland
# 45   58    Male  Cleveland
# 46   51    Male  Cleveland
# 47   50    Male  Cleveland
# 48   65  Female  Cleveland
# 49   53    Male  Cleveland
# 50   41  Female  Cleveland

# %%
df.loc[20:50, "age":"slope"] # loc with slicing first indexing 20 to 49 values showing in the age, dataset
# Out:
#     age     sex    dataset               cp  trestbps   chol    fbs  \
# 20   64    Male  Cleveland   typical angina     110.0  211.0  False
# 21   58  Female  Cleveland   typical angina     150.0  283.0   True
# 22   58    Male  Cleveland  atypical angina     120.0  284.0  False
# 23   58    Male  Cleveland      non-anginal     132.0  224.0  False
# 24   60    Male  Cleveland     asymptomatic     130.0  206.0  False
# 25   50  Female  Cleveland      non-anginal     120.0  219.0  False
# 26   58  Female  Cleveland      non-anginal     120.0  340.0  False
# 27   66  Female  Cleveland   typical angina     150.0  226.0  False
# 28   43    Male  Cleveland     asymptomatic     150.0  247.0  False
# 29   40    Male  Cleveland     asymptomatic     110.0  167.0  False
# 30   69  Female  Cleveland   typical angina     140.0  239.0  False
# 31   60    Male  Cleveland     asymptomatic     117.0  230.0   True
# 32   64    Male  Cleveland      non-anginal     140.0  335.0  False
# ...

# %%
df.loc[:, 'age'] # Age column all values showing or observing with slicing by the loc
# Out:
# 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 915    54
# 916    62
# 917    55
# 918    58
# 919    62
# Name: age, Length: 920, dtype: int64

# %%
df.loc[:50, 'age'] #Loc using slicing index 0 to 50 values showing|
# Out:
# 0     63
# 1     67
# 2     67
# 3     37
# 4     41
# 5     56
# 6     62
# 7     57
# 8     63
# 9     53
# 10    57
# 11    56
# 12    56
# 13    44
# 14    52
# 15    57
# 16    48
# 17    54
# 18    48
# 19    49
# 20    64
# 21    58
# 22    58
# 23    58
# 24    60
# 25    50
# 26    58
# 27    66
# 28    43
# 29    40
# 30    69
# 31    60
# 32    64
# 33    59
# 34    44
# 35    42
# 36    43
# 37    57
# 38    55
# 39    61
# 40    65
# 41    40
# 42    71
# 43    59
# 44    61
# 45    58
# 46    51
# 47    50
# 48    65
# 49    53
# 50    41
# Name: age, dtype: int64

# %%
df.loc[:50, ['age', 'dataset']] # loc with slicing first indexing 0 to 50 values showing in the age, dataset
# Out:
#     age    dataset
# 0    63  Cleveland
# 1    67  Cleveland
# 2    67  Cleveland
# 3    37  Cleveland
# 4    41  Cleveland
# 5    56  Cleveland
# 6    62  Cleveland
# 7    57  Cleveland
# 8    63  Cleveland
# 9    53  Cleveland
# 10   57  Cleveland
# 11   56  Cleveland
# 12   56  Cleveland
# 13   44  Cleveland
# 14   52  Cleveland
# 15   57  Cleveland
# 16   48  Cleveland
# 17   54  Cleveland
# 18   48  Cleveland
# 19   49  Cleveland
# 20   64  Cleveland
# 21   58  Cleveland
# 22   58  Cleveland
# 23   58  Cleveland
# 24   60  Cleveland
# 25   50  Cleveland
# 26   58  Cleveland
# 27   66  Cleveland
# 28   43  Cleveland
# 29   40  Cleveland
# 30   69  Cleveland
# 31   60  Cleveland
# 32   64  Cleveland
# 33   59  Cleveland
# 34   44  Cleveland
# 35   42  Cleveland
# 36   43  Cleveland
# 37   57  Cleveland
# 38   55  Cleveland
# 39   61  Cleveland
# 40   65  Cleveland
# 41   40  Cleveland
# 42   71  Cleveland
# 43   59  Cleveland
# 44   61  Cleveland
# 45   58  Cleveland
# ...

# %%
df.loc[:, ['age', 'dataset']] # loc with slicing first indexing all values showing in the age, dataset
# Out:
#      age        dataset
# 0     63      Cleveland
# 1     67      Cleveland
# 2     67      Cleveland
# 3     37      Cleveland
# 4     41      Cleveland
# ..   ...            ...
# 915   54  VA Long Beach
# 916   62  VA Long Beach
# 917   55  VA Long Beach
# 918   58  VA Long Beach
# 919   62  VA Long Beach
#
# [920 rows x 2 columns]

# %%
df.iloc[20:50, [1, 3]] # iloc with slicing first indexing 20 to 49 values showing in the age using index 1, dataset using index 3
# Out:
#     age    dataset
# 20   64  Cleveland
# 21   58  Cleveland
# 22   58  Cleveland
# 23   58  Cleveland
# 24   60  Cleveland
# 25   50  Cleveland
# 26   58  Cleveland
# 27   66  Cleveland
# 28   43  Cleveland
# 29   40  Cleveland
# 30   69  Cleveland
# 31   60  Cleveland
# 32   64  Cleveland
# 33   59  Cleveland
# 34   44  Cleveland
# 35   42  Cleveland
# 36   43  Cleveland
# 37   57  Cleveland
# 38   55  Cleveland
# 39   61  Cleveland
# 40   65  Cleveland
# 41   40  Cleveland
# 42   71  Cleveland
# 43   59  Cleveland
# 44   61  Cleveland
# 45   58  Cleveland
# 46   51  Cleveland
# 47   50  Cleveland
# 48   65  Cleveland
# 49   53  Cleveland

# %%
df.iloc[20:50, 1:4] # iloc with slicing first indexing 20 to 49 all values showing in the all column,
# and 1 is indexing value started age and 4 before stop 3 value which indexing ended dataset
# Out:
#     age     sex    dataset
# 20   64    Male  Cleveland
# 21   58  Female  Cleveland
# 22   58    Male  Cleveland
# 23   58    Male  Cleveland
# 24   60    Male  Cleveland
# 25   50  Female  Cleveland
# 26   58  Female  Cleveland
# 27   66  Female  Cleveland
# 28   43    Male  Cleveland
# 29   40    Male  Cleveland
# 30   69  Female  Cleveland
# 31   60    Male  Cleveland
# 32   64    Male  Cleveland
# 33   59    Male  Cleveland
# 34   44    Male  Cleveland
# 35   42    Male  Cleveland
# 36   43    Male  Cleveland
# 37   57    Male  Cleveland
# 38   55    Male  Cleveland
# 39   61    Male  Cleveland
# 40   65  Female  Cleveland
# 41   40    Male  Cleveland
# 42   71  Female  Cleveland
# 43   59    Male  Cleveland
# 44   61  Female  Cleveland
# 45   58    Male  Cleveland
# 46   51    Male  Cleveland
# 47   50    Male  Cleveland
# 48   65  Female  Cleveland
# 49   53    Male  Cleveland

# %%
df.iloc[20:50] # iloc with slicing first indexing 20 to 49 all values showing in the all column
# Out:
#     id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 20  21   64    Male  Cleveland   typical angina     110.0  211.0  False
# 21  22   58  Female  Cleveland   typical angina     150.0  283.0   True
# 22  23   58    Male  Cleveland  atypical angina     120.0  284.0  False
# 23  24   58    Male  Cleveland      non-anginal     132.0  224.0  False
# 24  25   60    Male  Cleveland     asymptomatic     130.0  206.0  False
# 25  26   50  Female  Cleveland      non-anginal     120.0  219.0  False
# 26  27   58  Female  Cleveland      non-anginal     120.0  340.0  False
# 27  28   66  Female  Cleveland   typical angina     150.0  226.0  False
# 28  29   43    Male  Cleveland     asymptomatic     150.0  247.0  False
# 29  30   40    Male  Cleveland     asymptomatic     110.0  167.0  False
# 30  31   69  Female  Cleveland   typical angina     140.0  239.0  False
# 31  32   60    Male  Cleveland     asymptomatic     117.0  230.0   True
# ...

# %%
df.shape # row, col
# Out:
# (920, 16)

# %%
df.info() #Datatype, observation and null find out
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
df.head() # First 5 observation dataset showing
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
df.head(7) # First 7 observation dataset showing
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# 5   6   56    Male  Cleveland  atypical angina     120.0  236.0  False
# 6   7   62  Female  Cleveland     asymptomatic     140.0  268.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
# ...

# %%
df.tail() # Last 5 observation dataset showing
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak slope  ca          thal  num
# 915  st-t abnormality   154.0  False      0.0   NaN NaN           NaN    1
# 916  st-t abnormality     NaN    NaN      NaN   NaN NaN           NaN    0
# 917  st-t abnormality   100.0  False      0.0   NaN NaN  fixed defect    2
# 918    lv hypertrophy     NaN    NaN      NaN   NaN NaN           NaN    0
# 919    lv hypertrophy    93.0   True      0.0   NaN NaN           NaN    1

# %%
df.tail(8) # Last 8 observation dataset showing
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 912  913   53    Male  VA Long Beach     asymptomatic     144.0  300.0   True
# 913  914   62    Male  VA Long Beach     asymptomatic     158.0  170.0  False
# 914  915   46    Male  VA Long Beach     asymptomatic     134.0  310.0  False
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak slope  ca          thal  num
# 912  st-t abnormality   128.0   True      1.5  flat NaN           NaN    3
# 913  st-t abnormality   138.0   True      0.0   NaN NaN           NaN    1
# ...

# %%
df['age'].mean() # mean value
# Out:
# 53.51086956521739

# %%
df['age'].median() # median value
# Out:
# 54.0

# %%
df['age'].mode() # mode value
# Out:
# 0    54
# Name: age, dtype: int64

# %%
df['age'].min() # Min value
# Out:
# 28

# %%
df['age'].max() # Max value
# Out:
# 77

# %%
df['age'].std() # the standard deviation of values
# Out:
# 9.424685209576857

# %%
df[['age', 'trestbps', 'thalch']].mean() # Short time finding out mean values
# Out:
# age          53.510870
# trestbps    132.132404
# thalch      137.545665
# dtype: float64

# %%
df[['age', 'trestbps', 'thalch']].mode() # Short time finding out mode values
# Out:
#    age  trestbps  thalch
# 0   54     120.0   150.0

# %%
df.describe() # All data describing value
# Out:
#                id         age    trestbps        chol      thalch     oldpeak  \
# count  920.000000  920.000000  861.000000  890.000000  865.000000  858.000000
# mean   460.500000   53.510870  132.132404  199.130337  137.545665    0.878788
# std    265.725422    9.424685   19.066070  110.780810   25.926276    1.091226
# min      1.000000   28.000000    0.000000    0.000000   60.000000   -2.600000
# 25%    230.750000   47.000000  120.000000  175.000000  120.000000    0.000000
# 50%    460.500000   54.000000  130.000000  223.000000  140.000000    0.500000
# 75%    690.250000   60.000000  140.000000  268.000000  157.000000    1.500000
# max    920.000000   77.000000  200.000000  603.000000  202.000000    6.200000
#
#                ca         num
# count  309.000000  920.000000
# mean     0.676375    0.995652
# std      0.935653    1.142693
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      1.000000    2.000000
# ...

# %%
df['sex'] # Descibe listing about which data
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 915    Female
# 916      Male
# 917      Male
# 918      Male
# 919      Male
# Name: sex, Length: 920, dtype: object

# %%
df['sex'].unique() # Showing all sex column which unique data haveing
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['sex'].nunique() #How to exactly category do yu have
# Out:
# 2

# %%
df['dataset'].nunique() #How to exactly category do yu have
# Out:
# 4

# %%
df['age'].unique() #How to exactly category do yu have all data
# Out:
# array([63, 67, 37, 41, 56, 62, 57, 53, 44, 52, 48, 54, 49, 64, 58, 60, 50,
#        66, 43, 40, 69, 59, 42, 55, 61, 65, 71, 51, 46, 45, 39, 68, 47, 34,
#        35, 29, 70, 77, 38, 74, 76, 28, 30, 31, 32, 33, 36, 72, 73, 75])

# %%
df['age'].nunique() #How to exactly category do yu have unique data
# Out:
# 50

# %%
df.describe(include='all') # All Column Report Count
# Out:
#                 id         age   sex    dataset            cp    trestbps  \
# count   920.000000  920.000000   920        920           920  861.000000
# unique         NaN         NaN     2          4             4         NaN
# top            NaN         NaN  Male  Cleveland  asymptomatic         NaN
# freq           NaN         NaN   726        304           496         NaN
# mean    460.500000   53.510870   NaN        NaN           NaN  132.132404
# std     265.725422    9.424685   NaN        NaN           NaN   19.066070
# min       1.000000   28.000000   NaN        NaN           NaN    0.000000
# 25%     230.750000   47.000000   NaN        NaN           NaN  120.000000
# 50%     460.500000   54.000000   NaN        NaN           NaN  130.000000
# 75%     690.250000   60.000000   NaN        NaN           NaN  140.000000
# max     920.000000   77.000000   NaN        NaN           NaN  200.000000
#
#               chol    fbs restecg      thalch  exang     oldpeak slope  \
# ...

# %%
df.describe(include=['O']) # Only for cateogrical Value Report Count, not using o leter and Mainly use Capital Letter
# Out:
#          sex    dataset            cp    fbs restecg  exang slope    thal
# count    920        920           920    830     918    865   611     434
# unique     2          4             4      2       3      2     3       3
# top     Male  Cleveland  asymptomatic  False  normal  False  flat  normal
# freq     726        304           496    692     551    528   345     196

# %%
df['dataset'].value_counts() # Dataset column, categoric and value count
# Out:
# dataset
# Cleveland        304
# Hungary          293
# VA Long Beach    200
# Switzerland      123
# Name: count, dtype: int64

# %%
df['slope'].value_counts() # Slope column, categoric and value count
# Out:
# slope
# flat           345
# upsloping      203
# downsloping     63
# Name: count, dtype: int64
