# %% [markdown]
# <a href="https://colab.research.google.com/github/jonaidsharif/Pandas-in-Python-A-to-Z-in-Bangla/blob/main/Pandas_Tutorial_11_Column_added%2C_remove.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # import library pandas, name direction pd
import numpy as np

# %%
# Python Dictionary

people_dict = {
    "first_name": "Jonaid Bin",
    "last_name": "Sharif",
    "email": "jonaidsharif@gmail.com",
    "company": "icu ac bd"
}

# %%
# Python Dictionary

more_people = {
    "matrix id": ["C201111", "C201129", "C201342", "C234214", "C123334", "C447233"],
    "first_name": ["Abdullah", "Mubian", "Ayub", "Tashfeen", "Huraain", "Jibon"],
    "last_name": ["Kareem", "Khannan", "Bodda", "Ahmeed", "Kalina", "Moron"],
    "email": ["abullah@gmail.com", "mubian@gmail.com", "ayubxtb@gmail.com", "Tashfeeeene@gmail.com", "Huraaineeei@gmail.com", "Jiboneimoren@gmail.com"],
    "company": ["ecologox", "brain station 23", "lead bd", "appcode", "sumsung r & d", "googleeiie"]
}

# %%
df = pd.DataFrame(more_people)

df
# Out:
#   matrix id first_name last_name                   email           company
# 0   C201111   Abdullah    Kareem       abullah@gmail.com          ecologox
# 1   C201129     Mubian   Khannan        mubian@gmail.com  brain station 23
# 2   C201342       Ayub     Bodda       ayubxtb@gmail.com           lead bd
# 3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com           appcode
# 4   C123334    Huraain    Kalina   Huraaineeei@gmail.com     sumsung r & d
# 5   C447233      Jibon     Moron  Jiboneimoren@gmail.com        googleeiie

# %%
df.loc[4] # checking about index 4 data
# Out:
# matrix id                   C123334
# first_name                  Huraain
# last_name                    Kalina
# email         Huraaineeei@gmail.com
# company               sumsung r & d
# Name: 4, dtype: object

# %%
df # Updating about data
# Out:
#   matrix id first_name last_name                   email           company
# 0   C201111   Abdullah    Kareem       abullah@gmail.com          ecologox
# 1   C201129     Mubian   Khannan        mubian@gmail.com  brain station 23
# 2   C201342       Ayub     Bodda       ayubxtb@gmail.com           lead bd
# 3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com           appcode
# 4   C123334    Huraain    Kalina   Huraaineeei@gmail.com     sumsung r & d
# 5   C447233      Jibon     Moron  Jiboneimoren@gmail.com        googleeiie

# %%
df.loc[4] = ['C210800', 'Humain', 'Kabir', 'kabir@gmail.com', 'jonaify'] # indexing 4 datatype replace

# %%
df # Updating about dataset
# Out:
#   matrix id first_name last_name                   email           company
# 0   C201111   Abdullah    Kareem       abullah@gmail.com          ecologox
# 1   C201129     Mubian   Khannan        mubian@gmail.com  brain station 23
# 2   C201342       Ayub     Bodda       ayubxtb@gmail.com           lead bd
# 3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com           appcode
# 4   C210800     Humain     Kabir         kabir@gmail.com           jonaify
# 5   C447233      Jibon     Moron  Jiboneimoren@gmail.com        googleeiie

# %%
df.loc[len(df), 'first_name'] = 'Adbullah' # Added New Column in the first_name and other name are NaN

# %%
df # Updating about dataset
# Out:
#   matrix id first_name last_name                   email           company
# 0   C201111   Abdullah    Kareem       abullah@gmail.com          ecologox
# 1   C201129     Mubian   Khannan        mubian@gmail.com  brain station 23
# 2   C201342       Ayub     Bodda       ayubxtb@gmail.com           lead bd
# 3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com           appcode
# 4   C210800     Humain     Kabir         kabir@gmail.com           jonaify
# 5   C447233      Jibon     Moron  Jiboneimoren@gmail.com        googleeiie
# 6       NaN   Adbullah       NaN                     NaN               NaN

# %%
df.loc[len(df), ['first_name', 'company']] = ['Jackie', 'One Click']
# Added new column in the first_name company and other name are NaN

# %%
df # Updating about my dataset
# Out:
#   matrix id first_name last_name                   email           company
# 0   C201111   Abdullah    Kareem       abullah@gmail.com          ecologox
# 1   C201129     Mubian   Khannan        mubian@gmail.com  brain station 23
# 2   C201342       Ayub     Bodda       ayubxtb@gmail.com           lead bd
# 3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com           appcode
# 4   C210800     Humain     Kabir         kabir@gmail.com           jonaify
# 5   C447233      Jibon     Moron  Jiboneimoren@gmail.com        googleeiie
# 6       NaN   Adbullah       NaN                     NaN               NaN
# 7       NaN     Jackie       NaN                     NaN         One Click

# %%
new_record = pd.DataFrame([{'first_name': 'Kalim', 'last_name': 'Azad'}]) # New record added to the dataset

# %%
new_record
# then showing to the index 0, but already index 0 here my dataset thats why we are using ignore_index function
# Out:
#   first_name last_name
# 0      Kalim      Azad

# %%
pd.concat([df, new_record], ignore_index = True)
# then previous command showing index 0, this cell we are using concat function to the added ignore index.
# automatically last new record added
# Out:
#   matrix id first_name last_name                   email           company
# 0   C201111   Abdullah    Kareem       abullah@gmail.com          ecologox
# 1   C201129     Mubian   Khannan        mubian@gmail.com  brain station 23
# 2   C201342       Ayub     Bodda       ayubxtb@gmail.com           lead bd
# 3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com           appcode
# 4   C210800     Humain     Kabir         kabir@gmail.com           jonaify
# 5   C447233      Jibon     Moron  Jiboneimoren@gmail.com        googleeiie
# 6       NaN   Adbullah       NaN                     NaN               NaN
# 7       NaN     Jackie       NaN                     NaN         One Click
# 8       NaN      Kalim      Azad                     NaN               NaN

# %%
df.drop(6) # if we are deleted our dataset row directly, drop thats command uses
# Out:
#   matrix id first_name last_name                   email           company
# 0   C201111   Abdullah    Kareem       abullah@gmail.com          ecologox
# 1   C201129     Mubian   Khannan        mubian@gmail.com  brain station 23
# 2   C201342       Ayub     Bodda       ayubxtb@gmail.com           lead bd
# 3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com           appcode
# 4   C210800     Humain     Kabir         kabir@gmail.com           jonaify
# 5   C447233      Jibon     Moron  Jiboneimoren@gmail.com        googleeiie
# 7       NaN     Jackie       NaN                     NaN         One Click

# %%
df.drop(7, inplace = True) # its the permanently deleted

# if we are deleted our dataset multi row directly, drop thats command uses

# %%
df # Updating about my dataset
# Out:
#   matrix id first_name last_name                   email           company
# 0   C201111   Abdullah    Kareem       abullah@gmail.com          ecologox
# 1   C201129     Mubian   Khannan        mubian@gmail.com  brain station 23
# 2   C201342       Ayub     Bodda       ayubxtb@gmail.com           lead bd
# 3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com           appcode
# 4   C210800     Humain     Kabir         kabir@gmail.com           jonaify
# 5   C447233      Jibon     Moron  Jiboneimoren@gmail.com        googleeiie
# 6       NaN   Adbullah       NaN                     NaN               NaN

# %%
df.reset_index(inplace=True) # Looks new index create, and added

# %%
df # Updating data permantenly
# Out:
#    index matrix id first_name last_name                   email  \
# 0      0   C201111   Abdullah    Kareem       abullah@gmail.com
# 1      1   C201129     Mubian   Khannan        mubian@gmail.com
# 2      2   C201342       Ayub     Bodda       ayubxtb@gmail.com
# 3      3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com
# 4      4   C210800     Humain     Kabir         kabir@gmail.com
# 5      5   C447233      Jibon     Moron  Jiboneimoren@gmail.com
# 6      6       NaN   Adbullah       NaN                     NaN
#
#             company
# 0          ecologox
# 1  brain station 23
# 2           lead bd
# 3           appcode
# 4           jonaify
# 5        googleeiie
# 6               NaN

# %%
df.reset_index(inplace=True, drop=True) # Again previous indexing create, added. this is not deleted

# %%
df # Updating data permantenly
# Out:
#    index matrix id first_name last_name                   email  \
# 0      0   C201111   Abdullah    Kareem       abullah@gmail.com
# 1      1   C201129     Mubian   Khannan        mubian@gmail.com
# 2      2   C201342       Ayub     Bodda       ayubxtb@gmail.com
# 3      3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com
# 4      4   C210800     Humain     Kabir         kabir@gmail.com
# 5      5   C447233      Jibon     Moron  Jiboneimoren@gmail.com
# 6      6       NaN   Adbullah       NaN                     NaN
#
#             company
# 0          ecologox
# 1  brain station 23
# 2           lead bd
# 3           appcode
# 4           jonaify
# 5        googleeiie
# 6               NaN

# %%
df['salary_year'] = [15000, 25100, 30000, 65555, 85555, 45555, 32222] # Added new column to the Salary_Year Column

# %%
df # Updated about dataset
# Out:
#    index matrix id first_name last_name                   email  \
# 0      0   C201111   Abdullah    Kareem       abullah@gmail.com
# 1      1   C201129     Mubian   Khannan        mubian@gmail.com
# 2      2   C201342       Ayub     Bodda       ayubxtb@gmail.com
# 3      3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com
# 4      4   C210800     Humain     Kabir         kabir@gmail.com
# 5      5   C447233      Jibon     Moron  Jiboneimoren@gmail.com
# 6      6       NaN   Adbullah       NaN                     NaN
#
#             company  Salary_Year  salary_year
# 0          ecologox        15000        15000
# 1  brain station 23        25100        25100
# 2           lead bd        30000        30000
# 3           appcode        65555        65555
# 4           jonaify        85555        85555
# 5        googleeiie        45555        45555
# 6               NaN        32222        32222

# %%
df['full_name'] = df['first_name'] + df['last_name']
# full_name column merge to the firstlast name addess with no middle space

# %%
df['full_name'] = df['first_name'] + " " + df['last_name']
# full_name column merge to the first and last name addess with middle space

# %%
df # Updated the dataset
# Out:
#    index matrix id first_name last_name                   email  \
# 0      0   C201111   Abdullah    Kareem       abullah@gmail.com
# 1      1   C201129     Mubian   Khannan        mubian@gmail.com
# 2      2   C201342       Ayub     Bodda       ayubxtb@gmail.com
# 3      3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com
# 4      4   C210800     Humain     Kabir         kabir@gmail.com
# 5      5   C447233      Jibon     Moron  Jiboneimoren@gmail.com
# 6      6       NaN   Adbullah       NaN                     NaN
#
#             company  Salary_Year  salary_year        full_name
# 0          ecologox        15000        15000  Abdullah Kareem
# 1  brain station 23        25100        25100   Mubian Khannan
# 2           lead bd        30000        30000       Ayub Bodda
# 3           appcode        65555        65555  Tashfeen Ahmeed
# 4           jonaify        85555        85555     Humain Kabir
# 5        googleeiie        45555        45555      Jibon Moron
# ...

# %%
df['full_name'].str.split(" ") # Normally dataset showing
# Out:
# 0    [Abdullah, Kareem]
# 1     [Mubian, Khannan]
# 2         [Ayub, Bodda]
# 3    [Tashfeen, Ahmeed]
# 4       [Humain, Kabir]
# 5        [Jibon, Moron]
# 6                   NaN
# Name: full_name, dtype: object

# %%
df['full_name'].str.split(" ", expand = True)
# Normally using expand then showing to the chart or table
# Out:
#           0        1
# 0  Abdullah   Kareem
# 1    Mubian  Khannan
# 2      Ayub    Bodda
# 3  Tashfeen   Ahmeed
# 4    Humain    Kabir
# 5     Jibon    Moron
# 6       NaN      NaN

# %%
df[['fn', 'ln']] = df['full_name'].str.split(" ", expand = True)
# previous cell we are create full name column 0 which is first name, and another one column 1 which is the last name

# %%
df # Updated about dataset
# Out:
#    index matrix id first_name last_name                   email  \
# 0      0   C201111   Abdullah    Kareem       abullah@gmail.com
# 1      1   C201129     Mubian   Khannan        mubian@gmail.com
# 2      2   C201342       Ayub     Bodda       ayubxtb@gmail.com
# 3      3   C234214   Tashfeen    Ahmeed   Tashfeeeene@gmail.com
# 4      4   C210800     Humain     Kabir         kabir@gmail.com
# 5      5   C447233      Jibon     Moron  Jiboneimoren@gmail.com
# 6      6       NaN   Adbullah       NaN                     NaN
#
#             company  Salary_Year  salary_year        full_name        fn  \
# 0          ecologox        15000        15000  Abdullah Kareem  Abdullah
# 1  brain station 23        25100        25100   Mubian Khannan    Mubian
# 2           lead bd        30000        30000       Ayub Bodda      Ayub
# 3           appcode        65555        65555  Tashfeen Ahmeed  Tashfeen
# 4           jonaify        85555        85555     Humain Kabir    Humain
# ...

# %%
df.drop(['first_name', 'last_name'], axis = 1, inplace = True)
# droping column which is the first_name, last_name coulmn

# %%
df # Updating about dataset
# Out:
#    index matrix id                   email           company  Salary_Year  \
# 0      0   C201111       abullah@gmail.com          ecologox        15000
# 1      1   C201129        mubian@gmail.com  brain station 23        25100
# 2      2   C201342       ayubxtb@gmail.com           lead bd        30000
# 3      3   C234214   Tashfeeeene@gmail.com           appcode        65555
# 4      4   C210800         kabir@gmail.com           jonaify        85555
# 5      5   C447233  Jiboneimoren@gmail.com        googleeiie        45555
# 6      6       NaN                     NaN               NaN        32222
#
#    salary_year        full_name        fn       ln
# 0        15000  Abdullah Kareem  Abdullah   Kareem
# 1        25100   Mubian Khannan    Mubian  Khannan
# 2        30000       Ayub Bodda      Ayub    Bodda
# 3        65555  Tashfeen Ahmeed  Tashfeen   Ahmeed
# 4        85555     Humain Kabir    Humain    Kabir
# 5        45555      Jibon Moron     Jibon    Moron
# ...
